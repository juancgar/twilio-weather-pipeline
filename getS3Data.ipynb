# %%
import pandas as pd
import os

import boto3, os, io

from io import BytesIO

import warnings
warnings.filterwarnings("ignore")

# %%
bucket_name = 'weather-innova-proto'
from dotenv import load_dotenv

load_dotenv(dotenv_path="Config.env")
my_key= os.getenv('AWS_KEY') 
my_secret= os.getenv('AWS_SECRET')

# %%
def getS3Object(s3Client,s3Bucket,filepath):
    f = s3Client.get_object(Bucket=s3Bucket, Key=filepath) 
    return pd.read_csv(io.BytesIO(f['Body'].read()), header=0,index_col=False)

# %%
def getAllS3Objects(s3key,s3Secret,s3Bucket):
    session = boto3.Session(aws_access_key_id=s3key,aws_secret_access_key=s3Secret) 
    s3Client = session.client('s3') 
    response = s3Client.list_objects(Bucket=s3Bucket).get('Contents', [])
    col = ["fecha","hour","condition","temp_C","will_rain","chance_of_rain"]
    df = pd.DataFrame(columns = col)
    for content in response:
        file = content.get('Key', [])
        df = df.append(getS3Object(s3Client,s3Bucket,file),ignore_index=True)

    return df

# %%
getAllS3Objects(my_key,my_secret,bucket_name)
# Out:
#           fecha hour                    condition  temp_C will_rain  \
# 0    2023-07-30    0         Patchy rain possible    24.7         0
# 1    2023-07-30    1  Thundery outbreaks possible    25.5         0
# 2    2023-07-30    2         Patchy rain possible    24.2         0
# 3    2023-07-30    3                Partly cloudy    23.9         0
# 4    2023-07-30    4                Partly cloudy    24.1         0
# ..          ...  ...                          ...     ...       ...
# 379  2023-08-15   19                        Clear    31.1         0
# 380  2023-08-15   20         Patchy rain possible    26.1         0
# 381  2023-08-15   21         Patchy rain possible    25.0         0
# 382  2023-08-15   22                Partly cloudy    26.4         0
# 383  2023-08-15   23       Moderate rain at times    24.6         0
#
#     chance_of_rain
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ..             ...
# 379              0
# 380              0
# 381              0
# 382              0
# 383              0
#
# [384 rows x 6 columns]
